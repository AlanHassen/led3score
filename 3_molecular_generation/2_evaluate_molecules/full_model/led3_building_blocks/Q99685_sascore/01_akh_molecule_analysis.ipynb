# %% [markdown]
# # Evaluate Molecular Generation Results

# %%
#ssh -L 8090:localhost:8090 c008

# %%
# !conda env list

# %% [markdown]
# ## compare the of csv and hdf files

# %%
csv_path = "<PATH>/led3_score/3_molecular_generation/2_evaluate_molecules/full_model/led3_building_blocks/Q99685_sascore/results/LED_BB_Q99685_SASCORE_FULL_MODEL_results.csv"

# load csv but dont read the trees column with pandas
import pandas 
csv_result = pandas.read_csv(csv_path, usecols = ["target","search_time","first_solution_time","first_solution_iteration","number_of_nodes","max_transforms","max_children","number_of_routes","number_of_solved_routes","top_score","is_solved","number_of_steps","number_of_precursors","number_of_precursors_in_stock","precursors_in_stock","precursors_not_in_stock","precursors_availability","policy_used_counts","profiling","top_scores"])
csv_result.head()
# Out:
#                                               target  search_time  \
# 0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1     0.820591
# 1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1    18.171343
# 2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1    15.373053
# 3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1     1.423994
# 4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1   900.409306
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.820526                         1                8
# 1            18.171283                        13              262
# 2            15.373009                         8              107
# 3             1.423924                         2               12
# 4             0.000000                         0             6219
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               7             1                 1                        1
# 1              10            13               143                        2
# 2              10             8                24                        1
# 3               7             2                 3                        1
# 4              10            28              1514                        0
#
#    top_score  is_solved  number_of_steps  number_of_precursors  \
# 0   0.952371       True                7                     5
# 1   0.952371       True                7                     5
# 2   0.950335       True                9                     7
# 3   0.986553       True                3                     3
# 4   0.855124      False               10                    10
#
#    number_of_precursors_in_stock  \
# 0                              5
# 1                              5
# 2                              7
# 3                              3
# 4                              9
#
#                                  precursors_in_stock precursors_not_in_stock  \
# 0  O=C(O)c1cccc(C(F)(F)F)c1, CC(C)(C)OC(=O)OC(=O)...                     NaN
# 1  ClCCN1CCCCC1, CC(C)(C)[Si](Cl)(c1ccccc1)c1cccc...                     NaN
# 2  C1CSCCN1, CC(C)(C)OC(=O)OC(=O)OC(C)(C)C, CC(C)...                     NaN
# 3  O=C(Cl)c1ccccc1, CC(C)(C)OC(=O)NC1CCNCC1, O=S(...                     NaN
# 4  Brc1ccccc1, CC1(C)OB(B2OC(C)(C)C(C)(C)O2)OC1(C...           O=Cn1nnc(S)n1
#
#                              precursors_availability policy_used_counts  \
# 0                           led3;led3;led3;led3;led3       {'uspto': 7}
# 1                           led3;led3;led3;led3;led3     {'uspto': 261}
# 2                 led3;led3;led3;led3;led3;led3;led3     {'uspto': 106}
# 3                                     led3;led3;led3      {'uspto': 11}
# 4  led3;led3;led3;led3;led3;led3;led3;led3;led3;N...    {'uspto': 6218}
#
#                                            profiling  \
# 0  {'expansion_calls': 7, 'reactants_generations'...
# 1  {'expansion_calls': 121, 'reactants_generation...
# 2  {'expansion_calls': 86, 'reactants_generations...
# 3  {'expansion_calls': 10, 'reactants_generations...
# 4  {'expansion_calls': 4854, 'reactants_generatio...
#
#                                           top_scores
# 0             0.9524, 0.7185, 0.6583, 0.6468, 0.5226
# 1  0.9524, 0.9524, 0.8144, 0.7976, 0.7940, 0.7940...
# 2  0.9503, 0.7926, 0.7920, 0.7920, 0.7920, 0.7920...
# 3             0.9866, 0.7259, 0.7185, 0.7149, 0.6699
# 4     0.8551, 0.8468, 0.8468, 0.8468, 0.8468, 0.8468

# %%
from multiretro.utils.io import DataReader

from typing import List

def load_values(paths: List[str], key: str = "table"):
    joined_df = None
    for path in paths:
        data_hdf = DataReader.load_hdf(path, key= key)
        if joined_df is None:
            joined_df = data_hdf
        else:
            joined_df = joined_df.append(data_hdf)
            
        joined_df.reset_index(drop=True, inplace=True)
    print(joined_df.columns)
    return joined_df

# %%
result_hdf_path = ["<PATH>/led3_score/3_molecular_generation/2_evaluate_molecules/full_model/led3_building_blocks/Q99685_sascore/results/LED_BB_Q99685_SASCORE_FULL_MODEL_results.csv_0_.hdf", "<PATH>/led3_score/3_molecular_generation/2_evaluate_molecules/full_model/led3_building_blocks/Q99685_sascore/results/LED_BB_Q99685_SASCORE_FULL_MODEL_results.csv_1_.hdf"]
hdf_results = load_values(result_hdf_path)
hdf_results.head()
# Out:
# Index(['index', 'target', 'search_time', 'first_solution_time',
#        'first_solution_iteration', 'number_of_nodes', 'max_transforms',
#        'max_children', 'number_of_routes', 'number_of_solved_routes',
#        'top_score', 'is_solved', 'number_of_steps', 'number_of_precursors',
#        'number_of_precursors_in_stock', 'precursors_in_stock',
#        'precursors_not_in_stock', 'precursors_availability',
#        'policy_used_counts', 'profiling', 'top_scores', 'trees'],
#       dtype='object')
# /tmp/ipykernel_242708/1801331223.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   joined_df = joined_df.append(data_hdf)
#    index                                             target  search_time  \
# 0      0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1     0.820591
# 1      1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1    18.171343
# 2      2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1    15.373053
# 3      3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1     1.423994
# 4      4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1   900.409306
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.820526                         1                8
# 1            18.171283                        13              262
# 2            15.373009                         8              107
# 3             1.423924                         2               12
# 4             0.000000                         0             6219
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               7             1                 1                        1
# 1              10            13               143                        2
# 2              10             8                24                        1
# 3               7             2                 3                        1
# 4              10            28              1514                        0
#
#    ...  number_of_steps  number_of_precursors  number_of_precursors_in_stock  \
# 0  ...                7                     5                              5
# 1  ...                7                     5                              5
# 2  ...                9                     7                              7
# 3  ...                3                     3                              3
# 4  ...               10                    10                              9
#
#                                  precursors_in_stock  precursors_not_in_stock  \
# 0  O=C(O)c1cccc(C(F)(F)F)c1, CC(C)(C)OC(=O)OC(=O)...
# 1  ClCCN1CCCCC1, CC(C)(C)[Si](Cl)(c1ccccc1)c1cccc...
# 2  C1CSCCN1, CC(C)(C)OC(=O)OC(=O)OC(C)(C)C, CC(C)...
# 3  O=C(Cl)c1ccccc1, CC(C)(C)OC(=O)NC1CCNCC1, O=S(...
# 4  Brc1ccccc1, CC1(C)OB(B2OC(C)(C)C(C)(C)O2)OC1(C...            O=Cn1nnc(S)n1
#
#                              precursors_availability policy_used_counts  \
# 0                           led3;led3;led3;led3;led3       {'uspto': 7}
# 1                           led3;led3;led3;led3;led3     {'uspto': 261}
# 2                 led3;led3;led3;led3;led3;led3;led3     {'uspto': 106}
# 3                                     led3;led3;led3      {'uspto': 11}
# 4  led3;led3;led3;led3;led3;led3;led3;led3;led3;N...    {'uspto': 6218}
#
#                                            profiling  \
# 0  {'expansion_calls': 7, 'reactants_generations'...
# 1  {'expansion_calls': 121, 'reactants_generation...
# 2  {'expansion_calls': 86, 'reactants_generations...
# 3  {'expansion_calls': 10, 'reactants_generations...
# 4  {'expansion_calls': 4854, 'reactants_generatio...
#
#                                           top_scores  \
# 0             0.9524, 0.7185, 0.6583, 0.6468, 0.5226
# 1  0.9524, 0.9524, 0.8144, 0.7976, 0.7940, 0.7940...
# 2  0.9503, 0.7926, 0.7920, 0.7920, 0.7920, 0.7920...
# 3             0.9866, 0.7259, 0.7185, 0.7149, 0.6699
# 4     0.8551, 0.8468, 0.8468, 0.8468, 0.8468, 0.8468
#
#                                                trees
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'CSc...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
# [5 rows x 22 columns]

# %%
# assert that the target column is the same for azf_results and csv_result
assert (hdf_results["target"] == csv_result["target"]).all()
# drop index column because it is the batch index
#hdf_results.drop(columns=["index"], inplace=True)
hdf_results.head()
# Out:
#    index                                             target  search_time  \
# 0      0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1     0.820591
# 1      1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1    18.171343
# 2      2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1    15.373053
# 3      3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1     1.423994
# 4      4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1   900.409306
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.820526                         1                8
# 1            18.171283                        13              262
# 2            15.373009                         8              107
# 3             1.423924                         2               12
# 4             0.000000                         0             6219
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               7             1                 1                        1
# 1              10            13               143                        2
# 2              10             8                24                        1
# 3               7             2                 3                        1
# 4              10            28              1514                        0
#
#    ...  number_of_steps  number_of_precursors  number_of_precursors_in_stock  \
# 0  ...                7                     5                              5
# 1  ...                7                     5                              5
# 2  ...                9                     7                              7
# 3  ...                3                     3                              3
# 4  ...               10                    10                              9
#
#                                  precursors_in_stock  precursors_not_in_stock  \
# 0  O=C(O)c1cccc(C(F)(F)F)c1, CC(C)(C)OC(=O)OC(=O)...
# 1  ClCCN1CCCCC1, CC(C)(C)[Si](Cl)(c1ccccc1)c1cccc...
# 2  C1CSCCN1, CC(C)(C)OC(=O)OC(=O)OC(C)(C)C, CC(C)...
# 3  O=C(Cl)c1ccccc1, CC(C)(C)OC(=O)NC1CCNCC1, O=S(...
# 4  Brc1ccccc1, CC1(C)OB(B2OC(C)(C)C(C)(C)O2)OC1(C...            O=Cn1nnc(S)n1
#
#                              precursors_availability policy_used_counts  \
# 0                           led3;led3;led3;led3;led3       {'uspto': 7}
# 1                           led3;led3;led3;led3;led3     {'uspto': 261}
# 2                 led3;led3;led3;led3;led3;led3;led3     {'uspto': 106}
# 3                                     led3;led3;led3      {'uspto': 11}
# 4  led3;led3;led3;led3;led3;led3;led3;led3;led3;N...    {'uspto': 6218}
#
#                                            profiling  \
# 0  {'expansion_calls': 7, 'reactants_generations'...
# 1  {'expansion_calls': 121, 'reactants_generation...
# 2  {'expansion_calls': 86, 'reactants_generations...
# 3  {'expansion_calls': 10, 'reactants_generations...
# 4  {'expansion_calls': 4854, 'reactants_generatio...
#
#                                           top_scores  \
# 0             0.9524, 0.7185, 0.6583, 0.6468, 0.5226
# 1  0.9524, 0.9524, 0.8144, 0.7976, 0.7940, 0.7940...
# 2  0.9503, 0.7926, 0.7920, 0.7920, 0.7920, 0.7920...
# 3             0.9866, 0.7259, 0.7185, 0.7149, 0.6699
# 4     0.8551, 0.8468, 0.8468, 0.8468, 0.8468, 0.8468
#
#                                                trees
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'CSc...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## calculate results on full data

# %%
solved_molecules = csv_result[csv_result["is_solved"] == True]
len(solved_molecules)
# Out:
# 58052

# %%
azf_results = AiZynthfinderResults(hdf_results)
solvability = azf_results.calculate_solvability()
print("The solvability: ", solvability)
# Out:
# The solvability:  58.05200000000001

# %%
hdf_results["number_of_steps"].hist()
# Out:
# <AxesSubplot:>

# %%
# get solved molecules
solved_molecules = hdf_results[hdf_results["is_solved"] == True]
solved_molecules["number_of_steps"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## calculate results on desired molecules

# %%
dataframe_with_values = "<PATH>/led3_score/data/results/3_molecular_generation/generated_molecules/full_model/used_scorer/sascore/generated_molecules/Q99685_sascore_400ep_final_cleaned.csv"
dataframe_with_values = pandas.read_csv(dataframe_with_values)
dataframe_with_values.head()
# Out:
#    LED3CHEMBL200KScorer  XGBClassifier  XGBRegressor        SA  \
# 0              0.992424       0.149867      6.061453  2.105179
# 1              0.992181       0.409173      6.090014  2.160051
# 2              0.473211       0.723250      7.351231  2.943341
# 3              0.999599       0.339404      5.825297  1.753736
# 4              0.978446       0.071252      5.510425  2.711330
#
#                                               SMILES  \
# 0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1
# 1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1
# 2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1
# 3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1
# 4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1
#
#                                         clean_smiles  \
# 0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1
# 1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1
# 2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1
# 3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1
# 4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1
#
#                                   clean_smiles_inchi
# 0  InChI=1S/C21H22F3NOS/c1-27-19-7-5-15(6-8-19)13...
# 1  InChI=1S/C26H28N2O3/c29-24-11-7-10-23(20-24)28...
# 2  InChI=1S/C20H28ClN3O3S/c1-20(2,3)27-19(26)24-9...
# 3  InChI=1S/C18H19ClN2O3S/c19-15-6-8-17(9-7-15)25...
# 4  InChI=1S/C14H11N5O2/c20-9-19-17-14(16-18-19)15...

# %%
# assert that the target column is the same for azf_results and csv_result
assert (hdf_results["target"] == dataframe_with_values["clean_smiles"]).all(), "The target column and clean_smiles columns are not the same"

# %%
# get the differences between the target and clean smiles
hdf_results[hdf_results["target"] != dataframe_with_values["clean_smiles"]]
# Out:
# Empty DataFrame
# Columns: [index, target, search_time, first_solution_time, first_solution_iteration, number_of_nodes, max_transforms, max_children, number_of_routes, number_of_solved_routes, top_score, is_solved, number_of_steps, number_of_precursors, number_of_precursors_in_stock, precursors_in_stock, precursors_not_in_stock, precursors_availability, policy_used_counts, profiling, top_scores, trees]
# Index: []
#
# [0 rows x 22 columns]

# %%
# calculate the inchis for the target column
from rdkit import Chem

def calculate_inchi(smiles):
    mol = Chem.MolFromSmiles(smiles)
    inchi = Chem.MolToInchi(mol)
    return inchi

hdf_results["target_inchi"] = hdf_results["target"].apply(calculate_inchi)

# %%
# do a compariosn between the target column and the clean_smiles column on inchi basis because smiles are disambigious
assert (hdf_results["target_inchi"] == dataframe_with_values["clean_smiles_inchi"]).all(), "The target column and clean_smiles columns INCHIS are not the same"
hdf_results[hdf_results["target_inchi"] != dataframe_with_values["clean_smiles_inchi"]]
#print the unique length and the normal length of the inchi column
print("The unique length of the inchi column: ", len(hdf_results["target_inchi"].unique()))
print("The normal length of the inchi column: ", len(hdf_results["target_inchi"]))

print("No join possible!")
# Out:
# The unique length of the inchi column:  99992
# The normal length of the inchi column:  100000
# No join possible!

# %%
# add the dataframe_with_values to the hdf_results for the columns LED3Scorer XGBClassifier	XGBRegressor clean_smiles_inchi
hdf_results["LED3CHEMBL200KScorer"] = dataframe_with_values["LED3CHEMBL200KScorer"]
hdf_results["XGBClassifier"] = dataframe_with_values["XGBClassifier"]
hdf_results["XGBRegressor"] = dataframe_with_values["XGBRegressor"]
hdf_results["SA"] = dataframe_with_values["SA"]
hdf_results["clean_smiles_inchi"] = dataframe_with_values["clean_smiles_inchi"]

assert (hdf_results["target_inchi"] == hdf_results["clean_smiles_inchi"]).all(), "The target column and clean_smiles columns INCHIS are not the same"

hdf_results.head()
# Out:
#    index                                             target  search_time  \
# 0      0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1     0.820591
# 1      1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1    18.171343
# 2      2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1    15.373053
# 3      3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1     1.423994
# 4      4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1   900.409306
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.820526                         1                8
# 1            18.171283                        13              262
# 2            15.373009                         8              107
# 3             1.423924                         2               12
# 4             0.000000                         0             6219
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               7             1                 1                        1
# 1              10            13               143                        2
# 2              10             8                24                        1
# 3               7             2                 3                        1
# 4              10            28              1514                        0
#
#    ...  policy_used_counts                                          profiling  \
# 0  ...        {'uspto': 7}  {'expansion_calls': 7, 'reactants_generations'...
# 1  ...      {'uspto': 261}  {'expansion_calls': 121, 'reactants_generation...
# 2  ...      {'uspto': 106}  {'expansion_calls': 86, 'reactants_generations...
# 3  ...       {'uspto': 11}  {'expansion_calls': 10, 'reactants_generations...
# 4  ...     {'uspto': 6218}  {'expansion_calls': 4854, 'reactants_generatio...
#
#                                           top_scores  \
# 0             0.9524, 0.7185, 0.6583, 0.6468, 0.5226
# 1  0.9524, 0.9524, 0.8144, 0.7976, 0.7940, 0.7940...
# 2  0.9503, 0.7926, 0.7920, 0.7920, 0.7920, 0.7920...
# 3             0.9866, 0.7259, 0.7185, 0.7149, 0.6699
# 4     0.8551, 0.8468, 0.8468, 0.8468, 0.8468, 0.8468
#
#                                                trees  \
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'CSc...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
#                                         target_inchi LED3CHEMBL200KScorer  \
# 0  InChI=1S/C21H22F3NOS/c1-27-19-7-5-15(6-8-19)13...             0.992424
# 1  InChI=1S/C26H28N2O3/c29-24-11-7-10-23(20-24)28...             0.992181
# 2  InChI=1S/C20H28ClN3O3S/c1-20(2,3)27-19(26)24-9...             0.473211
# 3  InChI=1S/C18H19ClN2O3S/c19-15-6-8-17(9-7-15)25...             0.999599
# 4  InChI=1S/C14H11N5O2/c20-9-19-17-14(16-18-19)15...             0.978446
#
#   XGBClassifier XGBRegressor        SA  \
# 0      0.149867     6.061453  2.105179
# 1      0.409173     6.090014  2.160051
# 2      0.723250     7.351231  2.943341
# 3      0.339404     5.825297  1.753736
# 4      0.071252     5.510425  2.711330
#
#                                   clean_smiles_inchi
# 0  InChI=1S/C21H22F3NOS/c1-27-19-7-5-15(6-8-19)13...
# 1  InChI=1S/C26H28N2O3/c29-24-11-7-10-23(20-24)28...
# 2  InChI=1S/C20H28ClN3O3S/c1-20(2,3)27-19(26)24-9...
# 3  InChI=1S/C18H19ClN2O3S/c19-15-6-8-17(9-7-15)25...
# 4  InChI=1S/C14H11N5O2/c20-9-19-17-14(16-18-19)15...
#
# [5 rows x 28 columns]

# %% [markdown]
# ## confusion matrix

# %%
predicted_solved = hdf_results["LED3CHEMBL200KScorer"] > 0.5
solved = hdf_results["is_solved"]

print("NOTE THESE VALUES ARE FOR THE PREDICTIONS WITH THE LED3CHEMBL200KSCORER WHICH IS NOT USED HERE!!! CAREFUL!!!")
# calculate the accuracy
from sklearn.metrics import accuracy_score
print("The accuracy: ", accuracy_score(solved, predicted_solved))

# calculate the precision
from sklearn.metrics import precision_score
print("The precision: ", precision_score(solved, predicted_solved))

# calculate the recall
from sklearn.metrics import recall_score
print("The recall: ", recall_score(solved, predicted_solved))

# calculate the f1 score
from sklearn.metrics import f1_score
print("The f1 score: ", f1_score(solved, predicted_solved))

# calculate the mcc
from sklearn.metrics import matthews_corrcoef
print("The mcc: ", matthews_corrcoef(solved, predicted_solved))

# visualize the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# normalized

confusion_matrix = confusion_matrix(solved, predicted_solved)
confusion_matrix = confusion_matrix.astype('float') / confusion_matrix.sum(axis=1)[:, numpy.newaxis]
sns.heatmap(confusion_matrix, annot=True, cmap="Blues", fmt=".2f")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# NOTE THESE VALUES ARE FOR THE PREDICTIONS WITH THE LED3CHEMBL200KSCORER WHICH IS NOT USED HERE!!! CAREFUL!!!
# The accuracy:  0.80044
# The precision:  0.7920934797276575
# The recall:  0.8897884655136774
# The f1 score:  0.8381035825545172
# The mcc:  0.5870107237510706

# %%
# NOTE THESE VALUES ARE FOR THE PREDICTIONS WITH THE LED3CHEMBL200KSCORER WHICH IS NOT USED HERE!!! CAREFUL

# %%
## clustering

# %%
from multiretro.data.logic.fingerprints.fingerprints import BinaryMorganFingerprint
from multiretro.data.logic.fingerprints.fingerprint_generator import FingerprintGenerator
from multiretro.visualization.logic.umapVisualization import UmapVisualizer

# generate fingerprints
morganFingerprint = BinaryMorganFingerprint(transform_to_numpy_array=False, radius=2, number_of_bits= 1024, use_features= False)
fingerprint_generator = FingerprintGenerator(fingerprint = morganFingerprint)
clustered_azf_results = fingerprint_generator.create_fingerprints_pandas_dataframe(data_frame = hdf_results, smiles_column = "target", fingerprint_column = "fingerprint")

umapVisualizer = UmapVisualizer(dataFrame=clustered_azf_results, dimensions=2)
umapVisualizer.transformRdkitColumn2NumpyArray(columnName="fingerprint", newColumnName="fingerprint_numpy_array")
umapVisualizer.transformNumpyArrayColumnn2NumpyMatrix(columnName="fingerprint_numpy_array")
umapVisualizer.calculateUmapMapper()
umapVisualizer.extractUmapEmbeddings()
#umapVisualizer.calculateMarkerSize(boolean_row = "Centroid")
umapDataFrame = umapVisualizer.getVisualizationDataFrame()
umapDataFrame = umapDataFrame.reset_index(drop = True)

# multiply the max_transforms by -1
umapDataFrame["number_of_steps_marker"] = umapDataFrame["number_of_steps"] * -1

# minmax scale the max_transforms_marker column
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(5, 25))
umapDataFrame["number_of_steps_marker"] = scaler.fit_transform(umapDataFrame[["number_of_steps_marker"]])
umapDataFrame["real_index"] = umapDataFrame.index.to_list()

# visualize the molecules
#umapVisualizer = UmapVisualizer(dataFrame=umapDataFrame)
#app = umapVisualizer.createMolPlotlyVisualization(smilesColumn = 'target', maximumMarkerSize = 25, size = "number_of_steps_marker", colorColumn = "is_solved", captionColumns = ["real_index", "is_solved","target","number_of_steps","LED3Scorer","XGBClassifier","XGBRegressor"])
#app.run_server(mode='jupyterlab',host='0.0.0.0', port=8000, debug=False, proxy=None, use_reloader=False)


# On Alice: ssh -L 8000:localhost:8000 node802
# At Home: ssh -L 8000:localhost:8000 hpc1
# Out:
# 2023-03-29 15:33:00.468 | INFO     | multiretro.data.logic.fingerprints.fingerprints:__init__:18 - Fingerprint Binary Morgan Fingerprint with Radius 2 and 1024 bits using Features: False initialized.
# <PATH>/workspace/anaconda/envs/multiretro/lib/python3.8/site-packages/umap/umap_.py:1802: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(

# %%
print(umapDataFrame.columns)

umapDataFrame = umapDataFrame.drop(columns=['trees', 'fingerprint', 'fingerprint_numpy_array'])
print(len(umapDataFrame))
umapDataFrame.head()
# Out:
# Index(['index', 'target', 'search_time', 'first_solution_time',
#        'first_solution_iteration', 'number_of_nodes', 'max_transforms',
#        'max_children', 'number_of_routes', 'number_of_solved_routes',
#        'top_score', 'is_solved', 'number_of_steps', 'number_of_precursors',
#        'number_of_precursors_in_stock', 'precursors_in_stock',
#        'precursors_not_in_stock', 'precursors_availability',
#        'policy_used_counts', 'profiling', 'top_scores', 'trees',
#        'target_inchi', 'LED3CHEMBL200KScorer', 'XGBClassifier', 'XGBRegressor',
#        'SA', 'clean_smiles_inchi', 'fingerprint', 'fingerprint_numpy_array',
#        'x', 'y', 'number_of_steps_marker', 'real_index'],
#       dtype='object')
# 100000
#    index                                             target  search_time  \
# 0      0     CSc1ccc(CC2CCN(C(=O)c3cccc(C(F)(F)F)c3)CC2)cc1     0.820591
# 1      1   O=C(c1ccc(OCCN2CCCCC2)cc1)N(c1ccccc1)c1cccc(O)c1    18.171343
# 2      2  CC(C)(C)OC(=O)N1CCN(C(=O)N2CCSCC2)CC1c1ccc(Cl)cc1    15.373053
# 3      3      O=C(NC1CCN(S(=O)(=O)c2ccc(Cl)cc2)CC1)c1ccccc1     1.423994
# 4      4                  O=Cn1nnc(Nc2cc(-c3ccccc3)ccc2O)n1   900.409306
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.820526                         1                8
# 1            18.171283                        13              262
# 2            15.373009                         8              107
# 3             1.423924                         2               12
# 4             0.000000                         0             6219
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               7             1                 1                        1
# 1              10            13               143                        2
# 2              10             8                24                        1
# 3               7             2                 3                        1
# 4              10            28              1514                        0
#
#    ...                                       target_inchi  \
# 0  ...  InChI=1S/C21H22F3NOS/c1-27-19-7-5-15(6-8-19)13...
# 1  ...  InChI=1S/C26H28N2O3/c29-24-11-7-10-23(20-24)28...
# 2  ...  InChI=1S/C20H28ClN3O3S/c1-20(2,3)27-19(26)24-9...
# 3  ...  InChI=1S/C18H19ClN2O3S/c19-15-6-8-17(9-7-15)25...
# 4  ...  InChI=1S/C14H11N5O2/c20-9-19-17-14(16-18-19)15...
#
#    LED3CHEMBL200KScorer  XGBClassifier  XGBRegressor        SA  \
# 0              0.992424       0.149867      6.061453  2.105179
# 1              0.992181       0.409173      6.090014  2.160051
# 2              0.473211       0.723250      7.351231  2.943341
# 3              0.999599       0.339404      5.825297  1.753736
# 4              0.978446       0.071252      5.510425  2.711330
#
#                                   clean_smiles_inchi          x         y  \
# 0  InChI=1S/C21H22F3NOS/c1-27-19-7-5-15(6-8-19)13...   4.709150  4.846460
# 1  InChI=1S/C26H28N2O3/c29-24-11-7-10-23(20-24)28...   7.456451  5.278953
# 2  InChI=1S/C20H28ClN3O3S/c1-20(2,3)27-19(26)24-9...   3.868821  4.954782
# 3  InChI=1S/C18H19ClN2O3S/c19-15-6-8-17(9-7-15)25...   6.972120  8.652215
# 4  InChI=1S/C14H11N5O2/c20-9-19-17-14(16-18-19)15...  13.750481  5.754843
#
#   number_of_steps_marker real_index
# 0                   11.0          0
# 1                   11.0          1
# 2                    7.0          2
# 3                   19.0          3
# 4                    5.0          4
#
# [5 rows x 31 columns]

# %%
save_path = "<PATH>/led3_score/data/results/3_molecular_generation/generated_molecules/full_model/used_scorer/sascore/planning_results/led3_building_blocks/LED_BB_Q99685_SASCORE_FULL_MODEL_results.csv"
#umapDataFrame.to_csv(save_path)

# %% [markdown]
# ## desired molecules (SA < 4.5, XGBClassifier > 0.8)

# %%
xgb_molecules = hdf_results[hdf_results["XGBClassifier"] > 0.8]
print("The number of molecules with a XGBClassifier score higher than 0.8: ", len(xgb_molecules))

xgb_molecules_solved = xgb_molecules[xgb_molecules["is_solved"] == True]
print("The number of molecules with a XGBClassifier score higher than 0.8 and are solved: ", len(xgb_molecules_solved))

sa_molecules = hdf_results[hdf_results["SA"] < 4]
print("The number of molecules with a SA score lower or equal than 4: ", len(sa_molecules))
short_list = hdf_results[(hdf_results["SA"] < 4) & (hdf_results["XGBClassifier"] > 0.8)]
print("The number of molecules with a SA score lower than 4 and a XGBClassifier score higher than 0.8: ", len(short_list))

short_list_solved = short_list[short_list["is_solved"] == True]
print("The number of molecules with a SA score lower than 4 and a XGBClassifier score higher than 0.8 and are solved: ", len(short_list_solved))
# Out:
# The number of molecules with a XGBClassifier score higher than 0.8:  7689
# The number of molecules with a XGBClassifier score higher than 0.8 and are solved:  2447
# The number of molecules with a SA score lower than 4:  90564
# The number of molecules with a SA score lower than 4 and a XGBClassifier score higher than 0.8:  4958
# The number of molecules with a SA score lower than 4 and a XGBClassifier score higher than 0.8 and are solved:  2371

# %%
import pandas

umapDataFrame = pandas.read_csv(save_path)

# %%
xgb_molecules = umapDataFrame[umapDataFrame["XGBClassifier"] > 0.8]
print("The number of molecules with a XGBClassifier score higher than 0.8: ", len(xgb_molecules))

xgb_molecules_solved = xgb_molecules[xgb_molecules["is_solved"] == True]
print("The number of molecules with a XGBClassifier score higher than 0.8 and are solved: ", len(xgb_molecules_solved))

sa_molecules = umapDataFrame[umapDataFrame["SA"] <= 4.5]
print("The number of molecules with a SA score lower or equal than 4.5: ", len(sa_molecules))
short_list = umapDataFrame[(umapDataFrame["SA"] <= 4.5) & (umapDataFrame["XGBClassifier"] > 0.8)]
print("The number of molecules with a SA score lower, equal than 4.5 and a XGBClassifier score higher than 0.8: ", len(short_list))

short_list_solved = short_list[short_list["is_solved"] == True]
print("The number of molecules with a SA score lower, equal than 4.5 and a XGBClassifier score higher than 0.8 and are solved: ", len(short_list_solved))
# Out:
# The number of molecules with a XGBClassifier score higher than 0.8:  7689
# The number of molecules with a XGBClassifier score higher than 0.8 and are solved:  2447
# The number of molecules with a SA score lower or equal than 4.5:  95331
# The number of molecules with a SA score lower, equal than 4.5 and a XGBClassifier score higher than 0.8:  6089
# The number of molecules with a SA score lower, equal than 4.5 and a XGBClassifier score higher than 0.8 and are solved:  2420
