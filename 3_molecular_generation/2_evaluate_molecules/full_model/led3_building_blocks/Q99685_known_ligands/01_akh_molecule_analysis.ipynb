# %% [markdown]
# # Evaluate Molecular Generation Results

# %%
#ssh -L 8090:localhost:8090 node854

# %%
# !conda env list

# %% [markdown]
# ## compare the of csv and hdf files

# %%
csv_path = "<PATH>/led3_score/3_molecular_generation/2_evaluate_molecules/full_model/led3_building_blocks/Q99685_known_ligands/LED_BB_Q99685_papyrus_known_ligands_cleaned.csv"

# load csv but dont read the trees column with pandas
import pandas 
csv_result = pandas.read_csv(csv_path, usecols = ["target","search_time","first_solution_time","first_solution_iteration","number_of_nodes","max_transforms","max_children","number_of_routes","number_of_solved_routes","top_score","is_solved","number_of_steps","number_of_precursors","number_of_precursors_in_stock","precursors_in_stock","precursors_not_in_stock","precursors_availability","policy_used_counts","profiling","top_scores"])
csv_result.head()
# Out:
#                                         target  search_time  \
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    top_score  is_solved  number_of_steps  number_of_precursors  \
# 0   0.975000       True                4                     3
# 1   0.986553       True                3                     4
# 2   0.997629       True                1                     2
# 3   0.994040       True                2                     3
# 4   0.950335       True                9                     7
#
#    number_of_precursors_in_stock  \
# 0                              3
# 1                              4
# 2                              2
# 3                              3
# 4                              7
#
#                                  precursors_in_stock precursors_not_in_stock  \
# 0         OCC1CO1, CCOC(=O)Cc1ccccc1, O=C(O)c1ccccc1                     NaN
# 1  NO, COc1ccc(Br)cc1, CCCCCCCCCC(=O)O, OB(O)c1cc...                     NaN
# 2                         Nc1ccccc1I, O=C1C=CC(=O)O1                     NaN
# 3         OB(O)c1ccccc1, Nc1ccccc1Br, O=C1C=CC(=O)O1                     NaN
# 4  O=C(Cl)Oc1ccc([N+](=O)[O-])cc1, CC(C)(C)OC(=O)...                     NaN
#
#               precursors_availability policy_used_counts  \
# 0                      led3;led3;led3       {'uspto': 5}
# 1                 led3;led3;led3;led3       {'uspto': 4}
# 2                           led3;led3       {'uspto': 1}
# 3                      led3;led3;led3       {'uspto': 3}
# 4  led3;led3;led3;led3;led3;led3;led3     {'uspto': 633}
#
#                                            profiling  \
# 0  {'expansion_calls': 4, 'reactants_generations'...
# 1  {'expansion_calls': 3, 'reactants_generations'...
# 2  {'expansion_calls': 1, 'reactants_generations'...
# 3  {'expansion_calls': 2, 'reactants_generations'...
# 4  {'expansion_calls': 574, 'reactants_generation...
#
#                                           top_scores
# 0             0.9750, 0.6583, 0.5226, 0.5190, 0.5116
# 1             0.9866, 0.6774, 0.6774, 0.5226, 0.0491
# 2                                     0.9976, 0.0491
# 3                     0.9940, 0.5226, 0.5226, 0.0491
# 4  0.9503, 0.8638, 0.8638, 0.8638, 0.8553, 0.8553...

# %%
from multiretro.utils.io import DataReader

from typing import List

def load_values(paths: List[str], key: str = "table"):
    joined_df = None
    for path in paths:
        data_hdf = DataReader.load_hdf(path, key= key)
        if joined_df is None:
            joined_df = data_hdf
        else:
            joined_df = joined_df.append(data_hdf)
            
        joined_df.reset_index(drop=True, inplace=True)
    print(joined_df.columns)
    return joined_df

# %%
result_hdf_path = ["<PATH>/led3_score/3_molecular_generation/2_evaluate_molecules/full_model/led3_building_blocks/Q99685_known_ligands/LED_BB_Q99685_papyrus_known_ligands_cleaned.csv.hdf"]
hdf_results = load_values(result_hdf_path)
hdf_results.head()
# Out:
# Index(['index', 'target', 'search_time', 'first_solution_time',
#        'first_solution_iteration', 'number_of_nodes', 'max_transforms',
#        'max_children', 'number_of_routes', 'number_of_solved_routes',
#        'top_score', 'is_solved', 'number_of_steps', 'number_of_precursors',
#        'number_of_precursors_in_stock', 'precursors_in_stock',
#        'precursors_not_in_stock', 'precursors_availability',
#        'policy_used_counts', 'profiling', 'top_scores', 'trees'],
#       dtype='object')
#    index                                       target  search_time  \
# 0      0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2      2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3      3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4      4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    ...  number_of_steps  number_of_precursors  number_of_precursors_in_stock  \
# 0  ...                4                     3                              3
# 1  ...                3                     4                              4
# 2  ...                1                     2                              2
# 3  ...                2                     3                              3
# 4  ...                9                     7                              7
#
#                                  precursors_in_stock  precursors_not_in_stock  \
# 0         OCC1CO1, CCOC(=O)Cc1ccccc1, O=C(O)c1ccccc1
# 1  NO, COc1ccc(Br)cc1, CCCCCCCCCC(=O)O, OB(O)c1cc...
# 2                         Nc1ccccc1I, O=C1C=CC(=O)O1
# 3         OB(O)c1ccccc1, Nc1ccccc1Br, O=C1C=CC(=O)O1
# 4  O=C(Cl)Oc1ccc([N+](=O)[O-])cc1, CC(C)(C)OC(=O)...
#
#               precursors_availability policy_used_counts  \
# 0                      led3;led3;led3       {'uspto': 5}
# 1                 led3;led3;led3;led3       {'uspto': 4}
# 2                           led3;led3       {'uspto': 1}
# 3                      led3;led3;led3       {'uspto': 3}
# 4  led3;led3;led3;led3;led3;led3;led3     {'uspto': 633}
#
#                                            profiling  \
# 0  {'expansion_calls': 4, 'reactants_generations'...
# 1  {'expansion_calls': 3, 'reactants_generations'...
# 2  {'expansion_calls': 1, 'reactants_generations'...
# 3  {'expansion_calls': 2, 'reactants_generations'...
# 4  {'expansion_calls': 574, 'reactants_generation...
#
#                                           top_scores  \
# 0             0.9750, 0.6583, 0.5226, 0.5190, 0.5116
# 1             0.9866, 0.6774, 0.6774, 0.5226, 0.0491
# 2                                     0.9976, 0.0491
# 3                     0.9940, 0.5226, 0.5226, 0.0491
# 4  0.9503, 0.8638, 0.8638, 0.8638, 0.8553, 0.8553...
#
#                                                trees
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
# [5 rows x 22 columns]

# %%
# assert that the target column is the same for azf_results and csv_result
assert (hdf_results["target"] == csv_result["target"]).all()
# drop index column because it is the batch index
hdf_results.drop(columns=["index"], inplace=True)
hdf_results.head()
# Out:
#                                         target  search_time  \
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    top_score  ...  number_of_steps  number_of_precursors  \
# 0   0.975000  ...                4                     3
# 1   0.986553  ...                3                     4
# 2   0.997629  ...                1                     2
# 3   0.994040  ...                2                     3
# 4   0.950335  ...                9                     7
#
#    number_of_precursors_in_stock  \
# 0                              3
# 1                              4
# 2                              2
# 3                              3
# 4                              7
#
#                                  precursors_in_stock precursors_not_in_stock  \
# 0         OCC1CO1, CCOC(=O)Cc1ccccc1, O=C(O)c1ccccc1
# 1  NO, COc1ccc(Br)cc1, CCCCCCCCCC(=O)O, OB(O)c1cc...
# 2                         Nc1ccccc1I, O=C1C=CC(=O)O1
# 3         OB(O)c1ccccc1, Nc1ccccc1Br, O=C1C=CC(=O)O1
# 4  O=C(Cl)Oc1ccc([N+](=O)[O-])cc1, CC(C)(C)OC(=O)...
#
#               precursors_availability policy_used_counts  \
# 0                      led3;led3;led3       {'uspto': 5}
# 1                 led3;led3;led3;led3       {'uspto': 4}
# 2                           led3;led3       {'uspto': 1}
# 3                      led3;led3;led3       {'uspto': 3}
# 4  led3;led3;led3;led3;led3;led3;led3     {'uspto': 633}
#
#                                            profiling  \
# 0  {'expansion_calls': 4, 'reactants_generations'...
# 1  {'expansion_calls': 3, 'reactants_generations'...
# 2  {'expansion_calls': 1, 'reactants_generations'...
# 3  {'expansion_calls': 2, 'reactants_generations'...
# 4  {'expansion_calls': 574, 'reactants_generation...
#
#                                           top_scores  \
# 0             0.9750, 0.6583, 0.5226, 0.5190, 0.5116
# 1             0.9866, 0.6774, 0.6774, 0.5226, 0.0491
# 2                                     0.9976, 0.0491
# 3                     0.9940, 0.5226, 0.5226, 0.0491
# 4  0.9503, 0.8638, 0.8638, 0.8638, 0.8553, 0.8553...
#
#                                                trees
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
# [5 rows x 21 columns]

# %% [markdown]
# ## calculate results on full data

# %%
solved_molecules = csv_result[csv_result["is_solved"] == True]
len(solved_molecules)
# Out:
# 545

# %%
azf_results = AiZynthfinderResults(hdf_results)
solvability = azf_results.calculate_solvability()
print("The solvability: ", solvability)
# Out:
# The solvability:  77.85714285714286

# %%
hdf_results["number_of_steps"].hist()
# Out:
# <AxesSubplot:>

# %%
# get solved molecules
solved_molecules = hdf_results[hdf_results["is_solved"] == True]
solved_molecules["number_of_steps"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## calculate results on desired molecules

# %%
dataframe_with_values = "<PATH>/led3_score/data/chemical_datasets/target_datasets/Q99685_papyrus_known_ligands/Q99685_papyrus_known_ligands_cleaned.csv"
dataframe_with_values = pandas.read_csv(dataframe_with_values)
dataframe_with_values.head()
# Out:
#                    Activity_ID Quality     source  \
# 0  AADKPDGTJHDJAJ_on_Q99685_WT    High   ChEMBL31
# 1  AAVJAASROXWJAI_on_Q99685_WT    High   ChEMBL31
# 2  AAZGPNZTJLHQJM_on_Q99685_WT    High  ExCAPE-DB
# 3  ABAMRMYDBGTLHX_on_Q99685_WT    High   ChEMBL31
# 4  AGLVDKDFDZSFKB_on_Q99685_WT    High   ChEMBL31
#
#                                                  CID  \
# 0  ChEMBL31.compound.177735;ChEMBL31.compound.177...
# 1                           ChEMBL31.compound.399047
# 2  599019;ChEMBL31.compound.123531;599019;ChEMBL3...
# 3                           ChEMBL31.compound.123534
# 4                           ChEMBL31.compound.467736
#
#                                           SMILES    connectivity  \
# 0               O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1  AADKPDGTJHDJAJ
# 1      CCCCCCCCCC(=NO)c1c(O)ccc(-c2ccc(OC)cc2)c1  AAVJAASROXWJAI
# 2                        O=C1C=CC(=O)N1c1ccccc1I  AAZGPNZTJLHQJM
# 3                O=C1C=CC(=O)N1c1ccccc1-c1ccccc1  ABAMRMYDBGTLHX
# 4  O=C1CCC(COC(=O)N2CCC(COc3c(Cl)cc(F)cc3)CC2)N1  AGLVDKDFDZSFKB
#
#                       InChIKey  \
# 0  AADKPDGTJHDJAJ-UHFFFAOYSA-N
# 1  AAVJAASROXWJAI-UHFFFAOYSA-N
# 2  AAZGPNZTJLHQJM-UHFFFAOYSA-N
# 3  ABAMRMYDBGTLHX-UHFFFAOYSA-N
# 4  AGLVDKDFDZSFKB-UHFFFAOYSA-N
#
#                                                InChI  \
# 0  InChI=1S/C18H18O3/c19-18(21-13-17-12-20-17)11-...
# 1  InChI=1S/C23H31NO3/c1-3-4-5-6-7-8-9-10-22(24-2...
# 2  InChI=1S/C10H6INO2/c11-7-3-1-2-4-8(7)12-9(13)5...
# 3  InChI=1S/C16H11NO2/c18-15-10-11-16(19)17(15)14...
# 4  InChI=1S/C18H22ClFN2O4/c19-15-9-13(20)1-3-16(1...
#
#                                        InChI_AuxInfo  target_id  ... relation  \
# 0  "AuxInfo=1/0/N:12,11,13,10,14,6,15,5,16,8,3,20...  Q99685_WT  ...        =
# 1  "AuxInfo=1/0/N:1,24,2,3,4,5,6,7,8,9,20,26,17,2...  Q99685_WT  ...        =
# 2  "AuxInfo=1/0/N:11,10,12,9,3,4,13,8,2,5,14,7,1,...  Q99685_WT  ...        =
# 3  "AuxInfo=1/0/N:17,16,18,11,10,15,19,12,9,3,4,1...  Q99685_WT  ...        =
# 4  "AuxInfo=1/1/N:22,4,23,3,12,24,11,25,19,14,6,1...  Q99685_WT  ...        =
#
#                                        pchembl_value pchembl_value_Mean  \
# 0  5.62;4.8;4.4;4.81;5.61;5.62;4.8;4.4;4.81;5.61;...              5.048
# 1                                          4.44;4.44              4.440
# 2                    5.3;5.3;5.3;5.3;5.3;5.3;5.3;5.3              5.300
# 3                                5.81;5.81;5.81;5.81              5.810
# 4                                          6.72;6.72              6.720
#
#   pchembl_value_StdDev pchembl_value_SEM  pchembl_value_N  \
# 0             0.498647          0.111501             20.0
# 1             0.000000          0.000000              2.0
# 2             0.000000          0.000000              8.0
# 3             0.000000          0.000000              4.0
# 4             0.000000          0.000000              2.0
#
#   pchembl_value_Median pchembl_value_MAD  \
# 0                 4.81              0.41
# 1                 4.44              0.00
# 2                 5.30              0.00
# 3                 5.81              0.00
# 4                 6.72              0.00
#
#                                   clean_smiles       clean_smiles_inchi_key
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1  AADKPDGTJHDJAJ-UHFFFAOYSA-N
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O  AAVJAASROXWJAI-UHFFFAOYSA-N
# 2                      O=C1C=CC(=O)N1c1ccccc1I  AAZGPNZTJLHQJM-UHFFFAOYSA-N
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1  ABAMRMYDBGTLHX-UHFFFAOYSA-N
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1  AGLVDKDFDZSFKB-UHFFFAOYSA-N
#
# [5 rows x 34 columns]

# %%
dataframe_with_values.columns
# Out:
# Index(['Activity_ID', 'Quality', 'source', 'CID', 'SMILES', 'connectivity',
#        'InChIKey', 'InChI', 'InChI_AuxInfo', 'target_id', 'TID', 'accession',
#        'Protein_Type', 'AID', 'doc_id', 'Year', 'all_doc_ids', 'all_years',
#        'type_IC50', 'type_EC50', 'type_KD', 'type_Ki', 'type_other',
#        'Activity_class', 'relation', 'pchembl_value', 'pchembl_value_Mean',
#        'pchembl_value_StdDev', 'pchembl_value_SEM', 'pchembl_value_N',
#        'pchembl_value_Median', 'pchembl_value_MAD', 'clean_smiles',
#        'clean_smiles_inchi_key'],
#       dtype='object')

# %%
# assert that the target column is the same for azf_results and csv_result
assert (hdf_results["target"] == dataframe_with_values["clean_smiles"]).all(), "The target column and clean_smiles columns are not the same"

# %%
# get the differences between the target and clean smiles
hdf_results[hdf_results["target"] != dataframe_with_values["clean_smiles"]]
# Out:
# Empty DataFrame
# Columns: [target, search_time, first_solution_time, first_solution_iteration, number_of_nodes, max_transforms, max_children, number_of_routes, number_of_solved_routes, top_score, is_solved, number_of_steps, number_of_precursors, number_of_precursors_in_stock, precursors_in_stock, precursors_not_in_stock, precursors_availability, policy_used_counts, profiling, top_scores, trees]
# Index: []
#
# [0 rows x 21 columns]

# %%
# rename target column to azf_target_smiles
hdf_results.rename(columns={"target": "azf_target_smiles"}, inplace=True)
hdf_results.head()
# Out:
#                              azf_target_smiles  search_time  \
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    top_score  ...  number_of_steps  number_of_precursors  \
# 0   0.975000  ...                4                     3
# 1   0.986553  ...                3                     4
# 2   0.997629  ...                1                     2
# 3   0.994040  ...                2                     3
# 4   0.950335  ...                9                     7
#
#    number_of_precursors_in_stock  \
# 0                              3
# 1                              4
# 2                              2
# 3                              3
# 4                              7
#
#                                  precursors_in_stock precursors_not_in_stock  \
# 0         OCC1CO1, CCOC(=O)Cc1ccccc1, O=C(O)c1ccccc1
# 1  NO, COc1ccc(Br)cc1, CCCCCCCCCC(=O)O, OB(O)c1cc...
# 2                         Nc1ccccc1I, O=C1C=CC(=O)O1
# 3         OB(O)c1ccccc1, Nc1ccccc1Br, O=C1C=CC(=O)O1
# 4  O=C(Cl)Oc1ccc([N+](=O)[O-])cc1, CC(C)(C)OC(=O)...
#
#               precursors_availability policy_used_counts  \
# 0                      led3;led3;led3       {'uspto': 5}
# 1                 led3;led3;led3;led3       {'uspto': 4}
# 2                           led3;led3       {'uspto': 1}
# 3                      led3;led3;led3       {'uspto': 3}
# 4  led3;led3;led3;led3;led3;led3;led3     {'uspto': 633}
#
#                                            profiling  \
# 0  {'expansion_calls': 4, 'reactants_generations'...
# 1  {'expansion_calls': 3, 'reactants_generations'...
# 2  {'expansion_calls': 1, 'reactants_generations'...
# 3  {'expansion_calls': 2, 'reactants_generations'...
# 4  {'expansion_calls': 574, 'reactants_generation...
#
#                                           top_scores  \
# 0             0.9750, 0.6583, 0.5226, 0.5190, 0.5116
# 1             0.9866, 0.6774, 0.6774, 0.5226, 0.0491
# 2                                     0.9976, 0.0491
# 3                     0.9940, 0.5226, 0.5226, 0.0491
# 4  0.9503, 0.8638, 0.8638, 0.8638, 0.8553, 0.8553...
#
#                                                trees
# 0  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 1  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 2  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 3  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
# 4  [{'type': 'mol', 'hide': False, 'smiles': 'O=C...
#
# [5 rows x 21 columns]

# %%
hdf_results.columns.isin(dataframe_with_values.columns)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
dataframe_with_values.columns.isin(hdf_results.columns)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
# add all dataframe_with_values columns to hdf_results
for column in dataframe_with_values.columns:
    hdf_results[column] = dataframe_with_values[column]

hdf_results.head()
# Out:
#                              azf_target_smiles  search_time  \
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    top_score  ...  relation  \
# 0   0.975000  ...         =
# 1   0.986553  ...         =
# 2   0.997629  ...         =
# 3   0.994040  ...         =
# 4   0.950335  ...         =
#
#                                        pchembl_value  pchembl_value_Mean  \
# 0  5.62;4.8;4.4;4.81;5.61;5.62;4.8;4.4;4.81;5.61;...               5.048
# 1                                          4.44;4.44               4.440
# 2                    5.3;5.3;5.3;5.3;5.3;5.3;5.3;5.3               5.300
# 3                                5.81;5.81;5.81;5.81               5.810
# 4                                          6.72;6.72               6.720
#
#    pchembl_value_StdDev pchembl_value_SEM pchembl_value_N  \
# 0              0.498647          0.111501            20.0
# 1              0.000000          0.000000             2.0
# 2              0.000000          0.000000             8.0
# 3              0.000000          0.000000             4.0
# 4              0.000000          0.000000             2.0
#
#   pchembl_value_Median pchembl_value_MAD  \
# 0                 4.81              0.41
# 1                 4.44              0.00
# 2                 5.30              0.00
# 3                 5.81              0.00
# 4                 6.72              0.00
#
#                                   clean_smiles       clean_smiles_inchi_key
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1  AADKPDGTJHDJAJ-UHFFFAOYSA-N
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O  AAVJAASROXWJAI-UHFFFAOYSA-N
# 2                      O=C1C=CC(=O)N1c1ccccc1I  AAZGPNZTJLHQJM-UHFFFAOYSA-N
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1  ABAMRMYDBGTLHX-UHFFFAOYSA-N
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1  AGLVDKDFDZSFKB-UHFFFAOYSA-N
#
# [5 rows x 55 columns]

# %% [markdown]
# ## clustering

# %%
from multiretro.data.logic.fingerprints.fingerprints import BinaryMorganFingerprint
from multiretro.data.logic.fingerprints.fingerprint_generator import FingerprintGenerator
from multiretro.visualization.logic.umapVisualization import UmapVisualizer

# generate fingerprints
morganFingerprint = BinaryMorganFingerprint(transform_to_numpy_array=False, radius=2, number_of_bits= 1024, use_features= False)
fingerprint_generator = FingerprintGenerator(fingerprint = morganFingerprint)
clustered_azf_results = fingerprint_generator.create_fingerprints_pandas_dataframe(data_frame = hdf_results, smiles_column = "azf_target_smiles", fingerprint_column = "fingerprint")

umapVisualizer = UmapVisualizer(dataFrame=clustered_azf_results, dimensions=2)
umapVisualizer.transformRdkitColumn2NumpyArray(columnName="fingerprint", newColumnName="fingerprint_numpy_array")
umapVisualizer.transformNumpyArrayColumnn2NumpyMatrix(columnName="fingerprint_numpy_array")
umapVisualizer.calculateUmapMapper()
umapVisualizer.extractUmapEmbeddings()
#umapVisualizer.calculateMarkerSize(boolean_row = "Centroid")
umapDataFrame = umapVisualizer.getVisualizationDataFrame()
umapDataFrame = umapDataFrame.reset_index(drop = True)

# multiply the max_transforms by -1
umapDataFrame["number_of_steps_marker"] = umapDataFrame["number_of_steps"] * -1

# minmax scale the max_transforms_marker column
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(5, 25))
umapDataFrame["number_of_steps_marker"] = scaler.fit_transform(umapDataFrame[["number_of_steps_marker"]])
umapDataFrame["real_index"] = umapDataFrame.index.to_list()

# visualize the molecules
#umapVisualizer = UmapVisualizer(dataFrame=umapDataFrame)
#app = umapVisualizer.createMolPlotlyVisualization(smilesColumn = 'target', maximumMarkerSize = 25, size = "number_of_steps_marker", colorColumn = "is_solved", captionColumns = ["real_index", "is_solved","target","number_of_steps","LED3Scorer","XGBClassifier","XGBRegressor"])
#app.run_server(mode='jupyterlab',host='0.0.0.0', port=8000, debug=False, proxy=None, use_reloader=False)


# On Alice: ssh -L 8000:localhost:8000 node802
# At Home: ssh -L 8000:localhost:8000 hpc1
# Out:
# 2023-04-27 22:23:11.837 | INFO     | multiretro.data.logic.fingerprints.fingerprints:__init__:18 - Fingerprint Binary Morgan Fingerprint with Radius 2 and 1024 bits using Features: False initialized.
# <PATH>/conda/envs/multiretro/lib/python3.8/site-packages/umap/umap_.py:1802: UserWarning: gradient function is not yet implemented for jaccard distance metric; inverse_transform will be unavailable
#   warn(

# %%
print(umapDataFrame.columns)

umapDataFrame = umapDataFrame.drop(columns=['trees', 'fingerprint', 'fingerprint_numpy_array'])
print(len(umapDataFrame))
umapDataFrame.head()
# Out:
# Index(['azf_target_smiles', 'search_time', 'first_solution_time',
#        'first_solution_iteration', 'number_of_nodes', 'max_transforms',
#        'max_children', 'number_of_routes', 'number_of_solved_routes',
#        'top_score', 'is_solved', 'number_of_steps', 'number_of_precursors',
#        'number_of_precursors_in_stock', 'precursors_in_stock',
#        'precursors_not_in_stock', 'precursors_availability',
#        'policy_used_counts', 'profiling', 'top_scores', 'trees', 'Activity_ID',
#        'Quality', 'source', 'CID', 'SMILES', 'connectivity', 'InChIKey',
#        'InChI', 'InChI_AuxInfo', 'target_id', 'TID', 'accession',
#        'Protein_Type', 'AID', 'doc_id', 'Year', 'all_doc_ids', 'all_years',
#        'type_IC50', 'type_EC50', 'type_KD', 'type_Ki', 'type_other',
#        'Activity_class', 'relation', 'pchembl_value', 'pchembl_value_Mean',
#        'pchembl_value_StdDev', 'pchembl_value_SEM', 'pchembl_value_N',
#        'pchembl_value_Median', 'pchembl_value_MAD', 'clean_smiles',
#        'clean_smiles_inchi_key', 'fingerprint', 'fingerprint_numpy_array', 'x',
#        'y', 'number_of_steps_marker', 'real_index'],
#       dtype='object')
# 700
#                              azf_target_smiles  search_time  \
# 0             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1     0.801095
# 1      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O     0.357490
# 2                      O=C1C=CC(=O)N1c1ccccc1I     0.092616
# 3              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1     0.210875
# 4  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1    92.835059
#
#    first_solution_time  first_solution_iteration  number_of_nodes  \
# 0             0.801032                         1                6
# 1             0.357419                         1                5
# 2             0.092547                         1                2
# 3             0.210809                         1                4
# 4            92.834986                        49              634
#
#    max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0               4             2                 2                        1
# 1               3             2                 2                        1
# 2               1             1                 1                        1
# 3               2             2                 2                        1
# 4              10            20                60                        1
#
#    top_score  ...  pchembl_value_SEM  pchembl_value_N  pchembl_value_Median  \
# 0   0.975000  ...           0.111501             20.0                  4.81
# 1   0.986553  ...           0.000000              2.0                  4.44
# 2   0.997629  ...           0.000000              8.0                  5.30
# 3   0.994040  ...           0.000000              4.0                  5.81
# 4   0.950335  ...           0.000000              2.0                  6.72
#
#    pchembl_value_MAD                                 clean_smiles  \
# 0               0.41             O=C(Cc1ccc(Cc2ccccc2)cc1)OCC1CO1
# 1               0.00      CCCCCCCCCC(=NO)c1cc(-c2ccc(OC)cc2)ccc1O
# 2               0.00                      O=C1C=CC(=O)N1c1ccccc1I
# 3               0.00              O=C1C=CC(=O)N1c1ccccc1-c1ccccc1
# 4               0.00  O=C1CCC(COC(=O)N2CCC(COc3ccc(F)cc3Cl)CC2)N1
#
#         clean_smiles_inchi_key          x         y number_of_steps_marker  \
# 0  AADKPDGTJHDJAJ-UHFFFAOYSA-N   1.982641  3.429419              18.333333
# 1  AAVJAASROXWJAI-UHFFFAOYSA-N  -9.245311 -1.185867              20.555556
# 2  AAZGPNZTJLHQJM-UHFFFAOYSA-N  -2.244598  4.500524              25.000000
# 3  ABAMRMYDBGTLHX-UHFFFAOYSA-N  -2.178477  4.551442              22.777778
# 4  AGLVDKDFDZSFKB-UHFFFAOYSA-N  18.573650 -3.887484               7.222222
#
#   real_index
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#
# [5 rows x 58 columns]

# %%
save_path = "<PATH>/led3_score/data/results/3_molecular_generation/generated_molecules/full_model/target_data/planning_results/led3_building_blocks/LED_BB_Q99685_papyrus_known_ligands_cleaned.csv"
#umapDataFrame.to_csv(save_path)
